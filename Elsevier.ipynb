# %%
from elsapy.elsclient import ElsClient
from elsapy.elsprofile import ElsAuthor, ElsAffil
from elsapy.elsdoc import FullDoc, AbsDoc
from elsapy.elssearch import ElsSearch
from urllib.parse import urlencode, quote_plus

# %%
## Read API key
con_file = open("elsevier_key.txt")
api_key = con_file.read()
con_file.close()

# %%
st = {'':'"star wars"'}
urlencode(st, quote_via=quote_plus)
# Out:
# '=%22star+wars%22'

# %%
class Elsevier_Searcher():
    __base_url = u'https://api.elsevier.com/content/search/'
    __api_key = u'e7882eed968063f188d6c53a919528a7'
    
    def __init__(self, index: str, apikey: str = __api_key): 
        self.articles_found = []
        self.apikey = apikey
        self.els_client = ElsClient(self.apikey)
        self._uri = self.__base_url + index + '?'
            
    def search(self, queryterms: list=None,
                    start_year: int=None, end_year: int=None,
                    content_type: str='journals', start_record: int=None, 
                    sort_field: str=None, sort_order: int=None, 
                    max_records: int=None, article_title: str = None, author: list = None):
        """
        @param queryterms: list of lists. Terms within the same list are
            separated by an OR. Lists are separated by an AND
        @param search_type: meta_data or querytext. 
            meta_data: This field enables a free-text search of all 
                configured metadata fields and the abstract. Accepts 
                complex queries involving field names and  boolean 
                operators.
            querytext: This field enables a free-text search of all 
                configured metadata fields, abstract and document text. 
                Accepts complex queries involving field names and boolean 
                operators. 
        @param start_year: Start value of Publication Year to restrict results by.
        @param end_year: End value of Publication Year to restrict results by.
        @param content_type: Note: these are case sensitive and must be spelled as 
            presented here to get a result: Journals, Conference, Early Access,
            Standards, Books, Courses
        @param start_record: Sequence number of first record to fetch. Default: 1
        @param sort_field: Field name on which to sort. Choose from: article_number
            article_title, author, publication_title, publication_year
        @param sort_order: asc (for ascending sort) or desc (for descending sort)
        @param max_records: The number of records to fetch. Maximum: 200
        
        @return  the data fields returned by the search are described by the 
            following link https://developer.ieee.org/docs/read/Metadata_API_responses
        """
        
        if not queryterms: 
            queryterms = self.queryterms
        
        formated_query = "("
        for index_group, group in enumerate(queryterms):
            if index_group > 0: 
                formated_query += ' AND ('
    #         else: 
    # #             formated_query += '('
            for index_term, term in enumerate(group): 
                if index_term > 0: 
                    formated_query += ' OR '
                if ' ' in term: 
                    formated_query += '('
                formated_query += f'"{term}"'
                if ' ' in term: 
                    formated_query += ')'

                if (index_term + 1) == len(group):
                    formated_query += ')'
        if author:
            str_author = ' AND '.join([f'"{x}"' for x in author])
            formated_query += f' AND aut({str_author})'
        if article_title:
            formated_query += f' AND ttl({article_title})'
        
        query_params = dict()
        
        query_params['query'] = formated_query
#         query_params['view'] = 'STANDARD'
            
        if start_year: 
            date = start_year
            if end_year: 
                date += f'-{end_year}'
            query_params['date'] = date
        if content_type: 
            query_params['content'] = content_type
        if start_record: 
            query_params['start'] = start_record
        if sort_field: 
            url += '&sort_field=' + sort_field 
        if sort_order: 
            url += '&sort_order=' + sort_order
        if max_records: 
            query_params['count'] = max_records
        
        get_all = True
        
        url = self._uri + urlencode(query_params, quote_via=quote_plus)
        print(url)
        
        self._api_response = self.els_client.exec_request(url)
        self._tot_num_res = int(self._api_response['search-results']['opensearch:totalResults'])
        self.results = self._api_response['search-results']['entry']
        print("a request completed...")
        if get_all is True:
            while (len(self.results) < self._tot_num_res) and (len(self.results) < 5000):
                for e in self._api_response['search-results']['link']:
                    if e['@ref'] == 'next':
                        next_url = e['@href']
                self._api_response = self.els_client.exec_request(next_url)
                self.results += self._api_response['search-results']['entry'] 
                print("a request completed...")

        return self.results

# %%
# ScienceDirect
#searcher = Elsevier_Searcher(apikey=api_key, index='scidir')

# Scopus
searcher = Elsevier_Searcher(index='scidir')

# %%
technology_queryterms = [
    'machine learning', 'deep learning', 'artificial intelligence',
    'neural network'
]

health_queryterms = [
    'coronary artery disease', 'chest pain', 'heart disease', 'MACE',
    'Acute Cardiac Complications'
]


searcher.search([technology_queryterms, health_queryterms], start_year=2010)
# Out:
# https://api.elsevier.com/content/search/scidir?query=%28%28%22machine+learning%22%29+OR+%28%22deep+learning%22%29+OR+%28%22artificial+intelligence%22%29+OR+%28%22neural+network%22%29%29+AND+%28%28%22coronary+artery+disease%22%29+OR+%28%22chest+pain%22%29+OR+%28%22heart+disease%22%29+OR+%22MACE%22+OR+%28%22Acute+Cardiac+Complications%22%29%29&date=2010&content=journals
# a request completed...
# a request completed...
# a request completed...
# a request completed...
# a request completed...
# a request completed...
# a request completed...
# [{'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'John',
#      'surname': 'Hayward'},
#     {'@_fa': 'true', 'given-name': 'Sergio A.', 'surname': 'Alvarez'},
#     {'@_fa': 'true', 'given-name': 'Carolina', 'surname': 'Ruiz'},
#     {'@_fa': 'true', 'given-name': 'Mary', 'surname': 'Sullivan'},
#     {'@_fa': 'true', 'given-name': 'Jennifer', 'surname': 'Tseng'},
#     {'@_fa': 'true', 'given-name': 'Giles', 'surname': 'Whalen'}]},
#   'dc:creator': 'John, Hayward',
#   'dc:identifier': 'DOI:10.1016/j.artmed.2010.04.009',
#   'dc:title': 'Machine learning of clinical performance in a pancreatic cancer database',
#   'eid': '1-s2.0-S0933365710000527',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0933365710000527',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0933365710000527',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0933-3657(10)00052-7',
#   'prism:coverDate': [{'$': '2010-07-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'July 2010',
#   'prism:doi': '10.1016/j.artmed.2010.04.009',
#   'prism:endingPage': '195',
#   'prism:issn': '09333657',
#   'prism:issueIdentifier': '3',
#   'prism:issueName': 'Data Mining for the Study of Disease Genes and Proteins',
#   'prism:publicationName': 'Artificial Intelligence in Medicine',
#   'prism:startingPage': '187',
#   'prism:teaser': 'We consider predictive models for clinical performance of pancreatic cancer patients based on machine learning techniques. The predictive performance of machine learning is compared with that of the...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0933365710000527',
#   'prism:volume': '49'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Ismail',
#      'surname': 'Babaoğlu'},
#     {'@_fa': 'true', 'given-name': 'Oğuz', 'surname': 'Fındık'},
#     {'@_fa': 'true', 'given-name': 'Mehmet', 'surname': 'Bayrak'}]},
#   'dc:creator': 'Ismail, Babaoğlu',
#   'dc:identifier': 'DOI:10.1016/j.eswa.2009.07.055',
#   'dc:title': 'Effects of principle component analysis on assessment of coronary artery diseases using support vector machine',
#   'eid': '1-s2.0-S0957417409007271',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0957417409007271',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0957417409007271',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0957-4174(09)00727-1',
#   'prism:coverDate': [{'$': '2010-03-15', '@_fa': 'true'}],
#   'prism:coverDisplayDate': '15 March 2010',
#   'prism:doi': '10.1016/j.eswa.2009.07.055',
#   'prism:endingPage': '2185',
#   'prism:issn': '09574174',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Expert Systems with Applications',
#   'prism:startingPage': '2182',
#   'prism:teaser': 'Artificial intelligence techniques are being effectively used in medical diagnostic support tools to increase the diagnostic accuracy and to provide additional knowledge to medical stuff. Effects of...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0957417409007271',
#   'prism:volume': '37'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'V.',
#      'surname': 'Indira'},
#     {'@_fa': 'true', 'given-name': 'R.', 'surname': 'Vasanthakumari'},
#     {'@_fa': 'true', 'given-name': 'V.', 'surname': 'Sugumaran'}]},
#   'dc:creator': 'V., Indira',
#   'dc:identifier': 'DOI:10.1016/j.eswa.2010.06.068',
#   'dc:title': 'Minimum sample size determination of vibration signals in machine learning approach to fault diagnosis using power analysis',
#   'eid': '1-s2.0-S0957417410005725',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0957417410005725',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0957417410005725',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0957-4174(10)00572-5',
#   'prism:coverDate': [{'$': '2010-12-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'December 2010',
#   'prism:doi': '10.1016/j.eswa.2010.06.068',
#   'prism:endingPage': '8658',
#   'prism:issn': '09574174',
#   'prism:issueIdentifier': '12',
#   'prism:publicationName': 'Expert Systems with Applications',
#   'prism:startingPage': '8650',
#   'prism:teaser': 'The machine learning approach to fault diagnosis consists of a chain of activities such as data acquisition, feature extraction, feature selection and classification. Each one is equally important in...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0957417410005725',
#   'prism:volume': '37'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Chih-Lin',
#      'surname': 'Chi'},
#     {'@_fa': 'true', 'given-name': 'W. Nick', 'surname': 'Street'},
#     {'@_fa': 'true', 'given-name': 'David A.', 'surname': 'Katz'}]},
#   'dc:creator': 'Chih-Lin, Chi',
#   'dc:identifier': 'DOI:10.1016/j.artmed.2010.08.001',
#   'dc:title': 'A decision support system for cost-effective diagnosis',
#   'eid': '1-s2.0-S0933365710001053',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0933365710001053',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0933365710001053',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0933-3657(10)00105-3',
#   'prism:coverDate': [{'$': '2010-11-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'November 2010',
#   'prism:doi': '10.1016/j.artmed.2010.08.001',
#   'prism:endingPage': '161',
#   'prism:issn': '09333657',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Artificial Intelligence in Medicine',
#   'prism:startingPage': '149',
#   'prism:teaser': 'Speed, cost, and accuracy are three important goals in disease diagnosis. This paper proposes a machine learning-based expert system algorithm to optimize these goals and assist diagnostic decisions...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0933365710001053',
#   'prism:volume': '50'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Resul',
#      'surname': 'Das'},
#     {'@_fa': 'true', 'given-name': 'Abdulkadir', 'surname': 'Sengur'}]},
#   'dc:creator': 'Resul, Das',
#   'dc:identifier': 'DOI:10.1016/j.eswa.2009.12.085',
#   'dc:title': 'Evaluation of ensemble methods for diagnosing of valvular heart disease',
#   'eid': '1-s2.0-S0957417409011312',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0957417409011312',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0957417409011312',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0957-4174(09)01131-2',
#   'prism:coverDate': [{'$': '2010-07-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'July 2010',
#   'prism:doi': '10.1016/j.eswa.2009.12.085',
#   'prism:endingPage': '5115',
#   'prism:issn': '09574174',
#   'prism:issueIdentifier': '7',
#   'prism:publicationName': 'Expert Systems with Applications',
#   'prism:startingPage': '5110',
#   'prism:teaser': 'In this work, we investigate the use of ensemble learning for improving classifiers which is one of the important directions in the current research of machine learning, in which bagging, boosting and...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0957417409011312',
#   'prism:volume': '37'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Ismail',
#      'surname': 'Babaoglu'},
#     {'@_fa': 'true', 'given-name': 'Omer Kaan', 'surname': 'Baykan'},
#     {'@_fa': 'true', 'given-name': 'Nazif', 'surname': 'Aygul'},
#     {'@_fa': 'true', 'given-name': 'Kurtulus', 'surname': 'Ozdemir'},
#     {'@_fa': 'true', 'given-name': 'Mehmet', 'surname': 'Bayrak'}]},
#   'dc:creator': 'Ismail, Babaoglu',
#   'dc:identifier': 'DOI:10.1016/j.eswa.2009.07.002',
#   'dc:title': 'Erratum “Assessment of exercise stress testing with artificial neural network in determining coronary artery disease and predicting lesion localization” [Experts Systems with Applications 36 (2P1) (2009) 2562–2566]',
#   'eid': '1-s2.0-S0957417409006630',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0957417409006630',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0957417409006630',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0957-4174(09)00663-0',
#   'prism:coverDate': [{'$': '2010-01-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'January 2010',
#   'prism:doi': '10.1016/j.eswa.2009.07.002',
#   'prism:issn': '09574174',
#   'prism:issueIdentifier': '1',
#   'prism:publicationName': 'Expert Systems with Applications',
#   'prism:startingPage': '905',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0957417409006630',
#   'prism:volume': '37',
#   'pubType': 'Erratum'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'V.',
#      'surname': 'Sujitha'},
#     {'@_fa': 'true', 'given-name': 'P.', 'surname': 'Sivagami'},
#     {'@_fa': 'true', 'given-name': 'M.S.', 'surname': 'Vijaya'}]},
#   'dc:creator': 'V., Sujitha',
#   'dc:identifier': 'DOI:10.1016/j.procs.2010.11.036',
#   'dc:title': 'Support vector machine based epilepsy prediction using textural features of MRI',
#   'eid': '1-s2.0-S1877050910003662',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1877050910003662',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1877050910003662',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://creativecommons.org/licenses/by-nc-nd/3.0/',
#   'pii': 'S1877-0509(10)00366-2',
#   'prism:coverDate': [{'$': '2010-01-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': '2010',
#   'prism:doi': '10.1016/j.procs.2010.11.036',
#   'prism:endingPage': '290',
#   'prism:issn': '18770509',
#   'prism:issueIdentifier': None,
#   'prism:issueName': 'Proceedings of the International Conference and Exhibition on Biometrics Technology',
#   'prism:publicationName': 'Procedia Computer Science',
#   'prism:startingPage': '283',
#   'prism:teaser': 'Epilepsy is a disorder of the central nervous system, specifically the brain. It is a neurological malfunction affecting about 1% of the population and is the third most common neurological disorder...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1877050910003662',
#   'prism:volume': '2',
#   'pubType': 'ICEBT 2010'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Kai M.',
#      'surname': 'Eggers'},
#     {'@_fa': 'true', 'given-name': 'Mikael', 'surname': 'Dellborg'},
#     {'@_fa': 'true', 'given-name': 'Nina', 'surname': 'Johnston'},
#     {'@_fa': 'true', 'given-name': 'Jonas', 'surname': 'Oldgren'},
#     {'@_fa': 'true', 'given-name': 'Eva', 'surname': 'Swahn'},
#     {'@_fa': 'true', 'given-name': 'Per', 'surname': 'Venge'},
#     {'@_fa': 'true', 'given-name': 'Bertil', 'surname': 'Lindahl'}]},
#   'dc:creator': 'Kai M., Eggers',
#   'dc:identifier': 'DOI:10.1016/j.clinbiochem.2009.09.026',
#   'dc:title': 'Myeloperoxidase is not useful for the early assessment of patients with chest pain',
#   'eid': '1-s2.0-S000991200900438X',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S000991200900438X',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S000991200900438X',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0009-9120(09)00438-X',
#   'prism:coverDate': [{'$': '2010-02-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'February 2010',
#   'prism:doi': '10.1016/j.clinbiochem.2009.09.026',
#   'prism:endingPage': '245',
#   'prism:issn': '00099120',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Clinical Biochemistry',
#   'prism:startingPage': '240',
#   'prism:teaser': 'Myeloperoxidase (MPO) has been listed as a potentially useful risk marker in acute coronary syndrome. However, its clinical utility in patients with acute chest pain is not yet defined....',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S000991200900438X',
#   'prism:volume': '43'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Anthony F.T.',
#      'surname': 'Brown'},
#     {'@_fa': 'true', 'given-name': 'Louise', 'surname': 'Cullen'},
#     {'@_fa': 'true', 'given-name': 'Martin', 'surname': 'Than'}]},
#   'dc:creator': 'Anthony F.T., Brown',
#   'dc:identifier': 'DOI:10.1016/j.mcna.2010.01.010',
#   'dc:title': 'Future Developments in Chest Pain Diagnosis and Management',
#   'eid': '1-s2.0-S0025712510000118',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0025712510000118',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0025712510000118',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0025-7125(10)00011-8',
#   'prism:coverDate': [{'$': '2010-03-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'March 2010',
#   'prism:doi': '10.1016/j.mcna.2010.01.010',
#   'prism:endingPage': '400',
#   'prism:issn': '00257125',
#   'prism:issueIdentifier': '2',
#   'prism:issueName': 'Chest Pain',
#   'prism:publicationName': 'Medical Clinics of North America',
#   'prism:startingPage': '375',
#   'prism:teaser': 'Much of the focus of research on patients with chest pain is directed at technological advances in the diagnosis and management of acute coronary syndrome (ACS), pulmonary embolism (PE), and acute aortic dissection (AAD), despite there being no significant difference at 4 years as regards mortality, ongoing chest pain, and quality of life between patients presenting to the emergency department with noncardiac chest pain and those with cardiac chest pain. This article examines future developments in the diagnosis and management of patients with suspected ACS, PE, AAD, gastrointestinal disease, and musculoskeletal chest pain.',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0025712510000118',
#   'prism:volume': '94'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'İsmail',
#      'surname': 'Babaoglu'},
#     {'@_fa': 'true', 'given-name': 'Oğuz', 'surname': 'Findik'},
#     {'@_fa': 'true', 'given-name': 'Erkan', 'surname': 'Ülker'}]},
#   'dc:creator': 'İsmail, Babaoglu',
#   'dc:identifier': 'DOI:10.1016/j.eswa.2009.09.064',
#   'dc:title': 'A comparison of feature selection models utilizing binary particle swarm optimization and genetic algorithm in determining coronary artery disease using support vector machine',
#   'eid': '1-s2.0-S0957417409008458',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0957417409008458',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0957417409008458',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0957-4174(09)00845-8',
#   'prism:coverDate': [{'$': '2010-04-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'April 2010',
#   'prism:doi': '10.1016/j.eswa.2009.09.064',
#   'prism:endingPage': '3183',
#   'prism:issn': '09574174',
#   'prism:issueIdentifier': '4',
#   'prism:publicationName': 'Expert Systems with Applications',
#   'prism:startingPage': '3177',
#   'prism:teaser': 'The aim of this study is to search the efficiency of binary particle swarm optimization (BPSO) and genetic algorithm (GA) techniques as feature selection models on determination of coronary artery disease...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0957417409008458',
#   'prism:volume': '37'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Ming',
#      'surname': 'Yang'},
#     {'@_fa': 'true', 'given-name': 'Jing', 'surname': 'Song'}]},
#   'dc:creator': 'Ming, Yang',
#   'dc:identifier': 'DOI:10.1016/j.neucom.2010.08.006',
#   'dc:title': 'A novel hypothesis-margin based approach for feature selection with side pairwise constraints',
#   'eid': '1-s2.0-S0925231210003322',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0925231210003322',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0925231210003322',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0925-2312(10)00332-2',
#   'prism:coverDate': [{'$': '2010-10-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'October 2010',
#   'prism:doi': '10.1016/j.neucom.2010.08.006',
#   'prism:endingPage': '2872',
#   'prism:issn': '09252312',
#   'prism:issueIdentifier': '16',
#   'prism:issueName': '10th Brazilian Symposium on Neural Networks (SBRN2008)',
#   'prism:publicationName': 'Neurocomputing',
#   'prism:startingPage': '2859',
#   'prism:teaser': 'Feature selection is an important problem for pattern classification systems. As compared to unsupervised feature selection methods, the supervised ones have better performance. However, almost all...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0925231210003322',
#   'prism:volume': '73'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Aaron',
#      'surname': 'Dennis'},
#     {'@_fa': 'true', 'given-name': 'Andrew D.', 'surname': 'Michaels'},
#     {'@_fa': 'true', 'given-name': 'Patti', 'surname': 'Arand'},
#     {'@_fa': 'true', 'given-name': 'Dan', 'surname': 'Ventura'}]},
#   'dc:creator': 'Aaron, Dennis',
#   'dc:identifier': 'DOI:10.1016/j.compbiomed.2010.07.003',
#   'dc:title': 'Noninvasive diagnosis of pulmonary hypertension using heart sound analysis',
#   'eid': '1-s2.0-S0010482510000983',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0010482510000983',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0010482510000983',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0010-4825(10)00098-3',
#   'prism:coverDate': [{'$': '2010-09-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'September 2010',
#   'prism:doi': '10.1016/j.compbiomed.2010.07.003',
#   'prism:endingPage': '764',
#   'prism:issn': '00104825',
#   'prism:issueIdentifier': '9',
#   'prism:publicationName': 'Computers in Biology and Medicine',
#   'prism:startingPage': '758',
#   'prism:teaser': 'Right-heart catheterization is the most accurate method for measuring pulmonary artery pressure (PAP). It is an expensive, invasive procedure, exposes patients to the risk of infection, and is not suited...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0010482510000983',
#   'prism:volume': '40'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Ataollah Ebrahim',
#      'surname': 'Zadeh'},
#     {'@_fa': 'true', 'given-name': 'Ali', 'surname': 'Khazaee'},
#     {'@_fa': 'true', 'given-name': 'Vahid', 'surname': 'Ranaee'}]},
#   'dc:creator': 'Ataollah Ebrahim, Zadeh',
#   'dc:identifier': 'DOI:10.1016/j.cmpb.2010.04.013',
#   'dc:title': 'Classification of the electrocardiogram signals using supervised classifiers and efficient features',
#   'eid': '1-s2.0-S0169260710001100',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0169260710001100',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0169260710001100',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0169-2607(10)00110-0',
#   'prism:coverDate': [{'$': '2010-08-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'August 2010',
#   'prism:doi': '10.1016/j.cmpb.2010.04.013',
#   'prism:endingPage': '194',
#   'prism:issn': '01692607',
#   'prism:issueIdentifier': '2',
#   'prism:publicationName': 'Computer Methods and Programs in Biomedicine',
#   'prism:startingPage': '179',
#   'prism:teaser': 'Automatic classification of electrocardiogram (ECG) signals is vital for clinical diagnosis of heart disease. This paper investigates the design of an efficient system for recognition of the premature...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0169260710001100',
#   'prism:volume': '99'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Daniel',
#      'surname': 'Rivero'},
#     {'@_fa': 'true', 'given-name': 'Julian', 'surname': 'Dorado'},
#     {'@_fa': 'true', 'given-name': 'Juan', 'surname': 'Rabuñal'},
#     {'@_fa': 'true', 'given-name': 'Alejandro', 'surname': 'Pazos'}]},
#   'dc:creator': 'Daniel, Rivero',
#   'dc:identifier': 'DOI:10.1016/j.neucom.2010.05.010',
#   'dc:title': 'Generation and simplification of Artificial Neural Networks by means of Genetic Programming',
#   'eid': '1-s2.0-S092523121000250X',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S092523121000250X',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S092523121000250X',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0925-2312(10)00250-X',
#   'prism:coverDate': [{'$': '2010-10-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'October 2010',
#   'prism:doi': '10.1016/j.neucom.2010.05.010',
#   'prism:endingPage': '3223',
#   'prism:issn': '09252312',
#   'prism:issueIdentifier': '16',
#   'prism:issueName': '10th Brazilian Symposium on Neural Networks (SBRN2008)',
#   'prism:publicationName': 'Neurocomputing',
#   'prism:startingPage': '3200',
#   'prism:teaser': 'The development of Artificial Neural Networks (ANNs) is traditionally a slow process in which human experts are needed to experiment on different architectural procedures until they find the one that...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S092523121000250X',
#   'prism:volume': '73'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Mohaddeseh',
#      'surname': 'Behjati'},
#     {'@_fa': 'true', 'given-name': 'Mohammad', 'surname': 'Hashemi'},
#     {'@_fa': 'true', 'given-name': 'Mansoor', 'surname': 'Salehi'},
#     {'@_fa': 'true', 'given-name': 'Roya', 'surname': 'Kelishadi'}]},
#   'dc:creator': 'Mohaddeseh, Behjati',
#   'dc:identifier': 'DOI:10.1016/j.ijcard.2008.12.120',
#   'dc:title': 'Can leukocyte telomere length (LTL) be considered as an index in application of neural network in the atherosclerosis risk stratification?',
#   'eid': '1-s2.0-S0167527308015714',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0167527308015714',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0167527308015714',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0167-5273(08)01571-4',
#   'prism:coverDate': [{'$': '2010-09-24', '@_fa': 'true'}],
#   'prism:coverDisplayDate': '24 September 2010',
#   'prism:doi': '10.1016/j.ijcard.2008.12.120',
#   'prism:endingPage': '137',
#   'prism:issn': '01675273',
#   'prism:issueIdentifier': '1',
#   'prism:publicationName': 'International Journal of Cardiology',
#   'prism:startingPage': '136',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0167527308015714',
#   'prism:volume': '144',
#   'pubType': 'Letter to the Editor'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Kai M.',
#      'surname': 'Eggers'},
#     {'@_fa': 'true', 'given-name': 'Tibor', 'surname': 'Kempf'},
#     {'@_fa': 'true', 'given-name': 'Per', 'surname': 'Venge'},
#     {'@_fa': 'true', 'given-name': 'Lars', 'surname': 'Wallentin'},
#     {'@_fa': 'true', 'given-name': 'Kai C.', 'surname': 'Wollert'},
#     {'@_fa': 'true', 'given-name': 'Bertil', 'surname': 'Lindahl'}]},
#   'dc:creator': 'Kai M., Eggers',
#   'dc:identifier': 'DOI:10.1016/j.ahj.2010.05.002',
#   'dc:title': 'Improving long-term risk prediction in patients with acute chest pain: The Global Registry of Acute Coronary Events (GRACE) risk score is enhanced by selected nonnecrosis biomarkers',
#   'eid': '1-s2.0-S0002870310003534',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0002870310003534',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0002870310003534',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0002-8703(10)00353-4',
#   'prism:coverDate': [{'$': '2010-07-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'July 2010',
#   'prism:doi': '10.1016/j.ahj.2010.05.002',
#   'prism:endingPage': '94',
#   'prism:issn': '00028703',
#   'prism:issueIdentifier': '1',
#   'prism:publicationName': 'American Heart Journal',
#   'prism:startingPage': '88',
#   'prism:teaser': 'The Global Registry of Acute Coronary Events (GRACE) risk score is widely recommended for risk assessment in patients with acute coronary syndrome. However, there is limited knowledge regarding the...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0002870310003534',
#   'prism:volume': '160',
#   'pubType': 'Clinical InvestigationAcute Ischemic Heart Disease'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Ataollah',
#      'surname': 'Ebrahimzadeh'},
#     {'@_fa': 'true', 'given-name': 'Ali', 'surname': 'Khazaee'}]},
#   'dc:creator': 'Ataollah, Ebrahimzadeh',
#   'dc:identifier': 'DOI:10.1016/j.measurement.2009.07.002',
#   'dc:title': 'Detection of premature ventricular contractions using MLP neural networks: A comparative study',
#   'eid': '1-s2.0-S0263224109001304',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0263224109001304',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0263224109001304',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0263-2241(09)00130-4',
#   'prism:coverDate': [{'$': '2010-01-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'January 2010',
#   'prism:doi': '10.1016/j.measurement.2009.07.002',
#   'prism:endingPage': '112',
#   'prism:issn': '02632241',
#   'prism:issueIdentifier': '1',
#   'prism:publicationName': 'Measurement',
#   'prism:startingPage': '103',
#   'prism:teaser': 'This paper proposes a three stage technique for detection of premature ventricular contraction (PVC) from normal beats and other heart diseases. This method includes a denoising module, a feature extraction...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0263224109001304',
#   'prism:volume': '43'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Turker',
#      'surname': 'Ince'},
#     {'@_fa': 'true', 'given-name': 'Serkan', 'surname': 'Kiranyaz'},
#     {'@_fa': 'true', 'given-name': 'Jenni', 'surname': 'Pulkkinen'},
#     {'@_fa': 'true', 'given-name': 'Moncef', 'surname': 'Gabbouj'}]},
#   'dc:creator': 'Turker, Ince',
#   'dc:identifier': 'DOI:10.1016/j.eswa.2010.05.033',
#   'dc:title': 'Evaluation of global and local training techniques over feed-forward neural network architecture spaces for computer-aided medical diagnosis',
#   'eid': '1-s2.0-S0957417410004446',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0957417410004446',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0957417410004446',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0957-4174(10)00444-6',
#   'prism:coverDate': [{'$': '2010-12-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'December 2010',
#   'prism:doi': '10.1016/j.eswa.2010.05.033',
#   'prism:endingPage': '8461',
#   'prism:issn': '09574174',
#   'prism:issueIdentifier': '12',
#   'prism:publicationName': 'Expert Systems with Applications',
#   'prism:startingPage': '8450',
#   'prism:teaser': 'In this paper, we investigate the performance of global vs. local techniques applied to the training of neural network classifiers for solving medical diagnosis problems. The presented methodology of...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0957417410004446',
#   'prism:volume': '37'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Pavel',
#      'surname': 'Kordík'},
#     {'@_fa': 'true', 'given-name': 'Jan', 'surname': 'Koutník'},
#     {'@_fa': 'true', 'given-name': 'Jan', 'surname': 'Drchal'},
#     {'@_fa': 'true', 'given-name': 'Oleg', 'surname': 'Kovářík'},
#     {'@_fa': 'true', 'given-name': 'Miroslav', 'surname': 'Čepek'},
#     {'@_fa': 'true', 'given-name': 'Miroslav', 'surname': 'Šnorek'}]},
#   'dc:creator': 'Pavel, Kordík',
#   'dc:identifier': 'DOI:10.1016/j.neunet.2010.02.003',
#   'dc:title': 'Meta-learning approach to neural network optimization',
#   'eid': '1-s2.0-S0893608010000456',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0893608010000456',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0893608010000456',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0893-6080(10)00045-6',
#   'prism:coverDate': [{'$': '2010-05-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'May 2010',
#   'prism:doi': '10.1016/j.neunet.2010.02.003',
#   'prism:endingPage': '582',
#   'prism:issn': '08936080',
#   'prism:issueIdentifier': '4',
#   'prism:issueName': 'The 18th International Conference on Artificial Neural Networks, ICANN 2008',
#   'prism:publicationName': 'Neural Networks',
#   'prism:startingPage': '568',
#   'prism:teaser': 'Optimization of neural network topology, weights and neuron transfer functions for given data set and problem is not an easy task. In this article, we focus primarily on building optimal feed-forward...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0893608010000456',
#   'prism:volume': '23',
#   'pubType': '2010 Special Issue'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Domenico',
#      'surname': 'Conforti'},
#     {'@_fa': 'true', 'given-name': 'Rosita', 'surname': 'Guido'}]},
#   'dc:creator': 'Domenico, Conforti',
#   'dc:identifier': 'DOI:10.1016/j.cor.2009.02.018',
#   'dc:title': 'Kernel based support vector machine via semidefinite programming: Application to medical diagnosis',
#   'eid': '1-s2.0-S0305054809000562',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0305054809000562',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0305054809000562',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0305-0548(09)00056-2',
#   'prism:coverDate': [{'$': '2010-08-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'August 2010',
#   'prism:doi': '10.1016/j.cor.2009.02.018',
#   'prism:endingPage': '1394',
#   'prism:issn': '03050548',
#   'prism:issueIdentifier': '8',
#   'prism:issueName': 'Operations Research and Data Mining in Biological Systems',
#   'prism:publicationName': 'Computers & Operations Research',
#   'prism:startingPage': '1389',
#   'prism:teaser': 'Support vector machine (SVM) is a well sound learning method and a robust classification procedure. Choosing a suitable kernel function in SVM is crucial for obtaining good performance; the difficulty...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0305054809000562',
#   'prism:volume': '37'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'El-Sayed Ahmed',
#      'surname': 'El-Dahshan'},
#     {'@_fa': 'true', 'given-name': 'Tamer', 'surname': 'Hosny'},
#     {'@_fa': 'true', 'given-name': 'Abdel-Badeeh M.', 'surname': 'Salem'}]},
#   'dc:creator': 'El-Sayed Ahmed, El-Dahshan',
#   'dc:identifier': 'DOI:10.1016/j.dsp.2009.07.002',
#   'dc:title': 'Hybrid intelligent techniques for MRI brain images classification',
#   'eid': '1-s2.0-S1051200409001377',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1051200409001377',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1051200409001377',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S1051-2004(09)00137-7',
#   'prism:coverDate': [{'$': '2010-03-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'March 2010',
#   'prism:doi': '10.1016/j.dsp.2009.07.002',
#   'prism:endingPage': '441',
#   'prism:issn': '10512004',
#   'prism:issueIdentifier': '2',
#   'prism:publicationName': 'Digital Signal Processing',
#   'prism:startingPage': '433',
#   'prism:teaser': 'This paper presents a hybrid technique for the classification of the magnetic resonance images (MRI). The proposed hybrid technique consists of three stages, namely, feature extraction, dimensionality...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1051200409001377',
#   'prism:volume': '20'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Yüksel',
#      'surname': 'Özbay'},
#     {'@_fa': 'true', 'given-name': 'Gülay', 'surname': 'Tezel'}]},
#   'dc:creator': 'Yüksel, Özbay',
#   'dc:identifier': 'DOI:10.1016/j.dsp.2009.10.016',
#   'dc:title': 'A new method for classification of ECG arrhythmias using neural network with adaptive activation function',
#   'eid': '1-s2.0-S1051200409001948',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1051200409001948',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1051200409001948',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S1051-2004(09)00194-8',
#   'prism:coverDate': [{'$': '2010-07-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'July 2010',
#   'prism:doi': '10.1016/j.dsp.2009.10.016',
#   'prism:endingPage': '1049',
#   'prism:issn': '10512004',
#   'prism:issueIdentifier': '4',
#   'prism:publicationName': 'Digital Signal Processing',
#   'prism:startingPage': '1040',
#   'prism:teaser': 'In this study, new neural network models with adaptive activation function (NNAAF) were implemented to classify ECG arrhythmias. Our NNAAF models included three types named as NNAAF-1, NNAAF-2 and NNAAf-3....',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1051200409001948',
#   'prism:volume': '20'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Wai-Kit',
#      'surname': 'Wong'},
#     {'@_fa': 'true', 'given-name': 'Chu-Kiong', 'surname': 'Loo'},
#     {'@_fa': 'true', 'given-name': 'Way-Soong', 'surname': 'Lim'},
#     {'@_fa': 'true', 'given-name': 'Poi-Ngee', 'surname': 'Tan'}]},
#   'dc:creator': 'Wai-Kit, Wong',
#   'dc:identifier': 'DOI:10.1016/j.neucom.2010.02.027',
#   'dc:title': 'Thermal condition monitoring system using log-polar mapping, quaternion correlation and max-product fuzzy neural network classification',
#   'eid': '1-s2.0-S0925231210003024',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0925231210003024',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0925231210003024',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0925-2312(10)00302-4',
#   'prism:coverDate': [{'$': '2010-12-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'December 2010',
#   'prism:doi': '10.1016/j.neucom.2010.02.027',
#   'prism:endingPage': '177',
#   'prism:issn': '09252312',
#   'prism:issueIdentifier': '1',
#   'prism:issueName': 'Artificial Brains',
#   'prism:publicationName': 'Neurocomputing',
#   'prism:startingPage': '164',
#   'prism:teaser': 'Nowadays, most factories rely on machines to help boost up their production and process. Therefore, an effective machine condition monitoring system plays an important role in these factories to ensure...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0925231210003024',
#   'prism:volume': '74'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Arit',
#      'surname': 'Thammano'},
#     {'@_fa': 'true', 'given-name': 'Jittraporn', 'surname': 'Moolwong'}]},
#   'dc:creator': 'Arit, Thammano',
#   'dc:identifier': 'DOI:10.1016/j.eswa.2009.06.046',
#   'dc:title': 'A new computational intelligence technique based on human group formation',
#   'eid': '1-s2.0-S095741740900606X',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S095741740900606X',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S095741740900606X',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0957-4174(09)00606-X',
#   'prism:coverDate': [{'$': '2010-03-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'March 2010',
#   'prism:doi': '10.1016/j.eswa.2009.06.046',
#   'prism:endingPage': '1634',
#   'prism:issn': '09574174',
#   'prism:issueIdentifier': '2',
#   'prism:publicationName': 'Expert Systems with Applications',
#   'prism:startingPage': '1628',
#   'prism:teaser': 'This paper proposes a novel computational intelligence technique, based on the sociological concept of human group formation, with the aim to acquire a better solution to classification problems. The...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S095741740900606X',
#   'prism:volume': '37'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Ping',
#      'surname': 'Wang'},
#     {'@_fa': 'true', 'given-name': 'Michael A.', 'surname': 'Acker'},
#     {'@_fa': 'true', 'given-name': 'Michel', 'surname': 'Bilello'},
#     {'@_fa': 'true', 'given-name': 'Elias R.', 'surname': 'Melhem'},
#     {'@_fa': 'true', 'given-name': 'Elizabeth', 'surname': 'Stambrook'},
#     {'@_fa': 'true', 'given-name': 'Sarah J.', 'surname': 'Ratcliffe'},
#     {'@_fa': 'true', 'given-name': 'Thomas F.', 'surname': 'Floyd'}],
#    'collaboration': [{'$': 'DENOVO (Determining Neurologic Outcomes from Valve Operations) Investigators',
#      '@_fa': 'true'}]},
#   'dc:creator': 'Ping, Wang',
#   'dc:identifier': 'DOI:10.1016/j.athoracsur.2010.04.016',
#   'dc:title': 'Sex, Aging, and Preexisting Cerebral Ischemic Disease in Patients With Aortic Stenosis',
#   'eid': '1-s2.0-S0003497510008040',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0003497510008040',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0003497510008040',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0003-4975(10)00804-0',
#   'prism:coverDate': [{'$': '2010-10-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'October 2010',
#   'prism:doi': '10.1016/j.athoracsur.2010.04.016',
#   'prism:endingPage': '1235',
#   'prism:issn': '00034975',
#   'prism:issueIdentifier': '4',
#   'prism:publicationName': 'The Annals of Thoracic Surgery',
#   'prism:startingPage': '1230',
#   'prism:teaser': 'Patients undergoing cardiac surgery have a high frequency of preexisting cerebral ischemic lesions, the presence of which appears to predict cognitive sequelae. Patients undergoing aortic valve replacement...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0003497510008040',
#   'prism:volume': '90',
#   'pubType': 'Original articleAdult cardiac'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Ian',
#      'surname': 'Rowlandson'},
#     {'@_fa': 'true', 'given-name': 'Joel', 'surname': 'Xue'},
#     {'@_fa': 'true', 'given-name': 'Robert', 'surname': 'Farrell'}]},
#   'dc:creator': 'Ian, Rowlandson',
#   'dc:identifier': 'DOI:10.1016/j.jelectrocard.2010.06.002',
#   'dc:title': 'Computerized STEMI recognition: an example of the art and science of building ECG algorithms',
#   'eid': '1-s2.0-S0022073610002608',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0022073610002608',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0022073610002608',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0022-0736(10)00260-8',
#   'prism:coverDate': [{'$': '2010-11-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'November–December 2010',
#   'prism:doi': '10.1016/j.jelectrocard.2010.06.002',
#   'prism:endingPage': '502',
#   'prism:issn': '00220736',
#   'prism:issueIdentifier': '6',
#   'prism:publicationName': 'Journal of Electrocardiology',
#   'prism:startingPage': '497',
#   'prism:teaser': 'With the advent of thrombolytics, guidelines for ST-elevated myocardial infarction (STEMI) recognition were presented in terms of an ST segment exceeding a particular level (1 or 2 mm) in 2 contiguous...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0022073610002608',
#   'prism:volume': '43'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Rui',
#      'surname': 'Xu'},
#     {'@_fa': 'true', 'given-name': 'Steven', 'surname': 'Damelin'},
#     {'@_fa': 'true', 'given-name': 'Boaz', 'surname': 'Nadler'},
#     {'@_fa': 'true', 'given-name': 'Donald C.', 'surname': 'Wunsch'}]},
#   'dc:creator': 'Rui, Xu',
#   'dc:identifier': 'DOI:10.1016/j.artmed.2009.06.001',
#   'dc:title': 'Clustering of high-dimensional gene expression data with feature filtering methods and diffusion maps',
#   'eid': '1-s2.0-S0933365709001006',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0933365709001006',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0933365709001006',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0933-3657(09)00100-6',
#   'prism:coverDate': [{'$': '2010-02-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'February–March 2010',
#   'prism:doi': '10.1016/j.artmed.2009.06.001',
#   'prism:endingPage': '98',
#   'prism:issn': '09333657',
#   'prism:issueIdentifier': '2',
#   'prism:issueName': 'Artificial Intelligence in Biomedical Engineering and Informatics',
#   'prism:publicationName': 'Artificial Intelligence in Medicine',
#   'prism:startingPage': '91',
#   'prism:teaser': 'The importance of gene expression data in cancer diagnosis and treatment has become widely known by cancer researchers in recent years. However, one of the major challenges in the computational analysis...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0933365709001006',
#   'prism:volume': '48'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Peter',
#      'surname': 'Revesz'},
#     {'@_fa': 'true', 'given-name': 'Thomas', 'surname': 'Triplet'}]},
#   'dc:creator': 'Peter, Revesz',
#   'dc:identifier': 'DOI:10.1016/j.artmed.2010.02.003',
#   'dc:title': 'Classification integration and reclassification using constraint databases',
#   'eid': '1-s2.0-S0933365710000242',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0933365710000242',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0933365710000242',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0933-3657(10)00024-2',
#   'prism:coverDate': [{'$': '2010-06-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'June 2010',
#   'prism:doi': '10.1016/j.artmed.2010.02.003',
#   'prism:endingPage': '91',
#   'prism:issn': '09333657',
#   'prism:issueIdentifier': '2',
#   'prism:publicationName': 'Artificial Intelligence in Medicine',
#   'prism:startingPage': '79',
#   'prism:teaser': 'We propose classification integration as a new method for data integration from different sources. We also propose reclassification as a new method of combining existing medical classifications for...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0933365710000242',
#   'prism:volume': '49'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Jui-Chen',
#      'surname': 'Huang'}]},
#   'dc:creator': 'Jui-Chen, Huang',
#   'dc:identifier': 'DOI:10.1016/j.eswa.2009.05.063',
#   'dc:title': 'Remote health monitoring adoption model based on artificial neural networks',
#   'eid': '1-s2.0-S0957417409005041',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0957417409005041',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0957417409005041',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0957-4174(09)00504-1',
#   'prism:coverDate': [{'$': '2010-01-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'January 2010',
#   'prism:doi': '10.1016/j.eswa.2009.05.063',
#   'prism:endingPage': '314',
#   'prism:issn': '09574174',
#   'prism:issueIdentifier': '1',
#   'prism:publicationName': 'Expert Systems with Applications',
#   'prism:startingPage': '307',
#   'prism:teaser': 'The purpose of this research is to utilize the adoption model of remote health monitoring established by artificial neural networks (ANNs). The adoption model by the naming is the healthcare information...',
# ...
#   'prism:volume': '30'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true', 'given-name': 'Z', 'surname': 'Cao'},
#     {'@_fa': 'true', 'given-name': 'J', 'surname': 'Margolis'},
#     {'@_fa': 'true', 'given-name': 'T', 'surname': 'Mark'}]},
#   'dc:creator': 'Z, Cao',
#   'dc:identifier': 'DOI:10.1016/S1098-3015(10)72089-1',
#   'dc:title': 'PMC46 COMPARISON OF DIFFERENCE-IN-DIFFERENCE AND PROPENSITY SCORE METHODS IN REGRESSIONS WITH BINARY OUTCOMES',
#   'eid': '1-s2.0-S1098301510720891',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1098301510720891',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1098301510720891',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': True,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/',
#   'pii': 'S1098-3015(10)72089-1',
#   'prism:coverDate': [{'$': '2010-05-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'May 2010',
#   'prism:doi': '10.1016/S1098-3015(10)72089-1',
#   'prism:issn': '10983015',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Value in Health',
#   'prism:startingPage': 'A22',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1098301510720891',
#   'prism:volume': '13',
#   'pubType': 'POSTER SESSION ICONCEPTUAL PAPERS & RESEARCH ON METHODS – Statistical Methods'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'ML',
#      'surname': 'Martin'}]},
#   'dc:creator': 'ML, Martin',
#   'dc:identifier': 'DOI:10.1016/S1098-3015(10)72086-6',
#   'dc:title': 'PMC43 EIGHT KEY EVIDENCES FOR CONTENT VALIDITY OF PATIENT REPORTED OUTCOME (PRO) INSTRUMENTS',
#   'eid': '1-s2.0-S1098301510720866',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1098301510720866',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1098301510720866',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': True,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/',
#   'pii': 'S1098-3015(10)72086-6',
#   'prism:coverDate': [{'$': '2010-05-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'May 2010',
#   'prism:doi': '10.1016/S1098-3015(10)72086-6',
#   'prism:issn': '10983015',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Value in Health',
#   'prism:startingPage': 'A22',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1098301510720866',
#   'prism:volume': '13',
#   'pubType': 'POSTER SESSION ICONCEPTUAL PAPERS & RESEARCH ON METHODS – Patient-Reported Outcomes Studies'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true', 'given-name': 'X', 'surname': 'Luo'},
#     {'@_fa': 'true', 'given-name': 'JW', 'surname': 'Shaw'},
#     {'@_fa': 'true', 'given-name': 'AS', 'surname': 'Pickard'},
#     {'@_fa': 'true', 'given-name': 'S', 'surname': 'Walton'}]},
#   'dc:creator': 'X, Luo',
#   'dc:identifier': 'DOI:10.1016/S1098-3015(10)72087-8',
#   'dc:title': 'PMC44 AN EVALUATION OF THE STATISTICAL EFFICIENCY OF THE US POPULATION MEDIAN-BASED EQ-5D INDEX USING DATA FROM THE MEDICAL EXPENDITURE PANEL SURVEY',
#   'eid': '1-s2.0-S1098301510720878',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1098301510720878',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1098301510720878',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': True,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/',
#   'pii': 'S1098-3015(10)72087-8',
#   'prism:coverDate': [{'$': '2010-05-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'May 2010',
#   'prism:doi': '10.1016/S1098-3015(10)72087-8',
#   'prism:issn': '10983015',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Value in Health',
#   'prism:startingPage': 'A22',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1098301510720878',
#   'prism:volume': '13',
#   'pubType': 'POSTER SESSION ICONCEPTUAL PAPERS & RESEARCH ON METHODS – Patient-Reported Outcomes Studies'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'T',
#      'surname': 'Shimbo'},
#     {'@_fa': 'true', 'given-name': 'K', 'surname': 'Miyaki'},
#     {'@_fa': 'true', 'given-name': 'M', 'surname': 'Sakai'},
#     {'@_fa': 'true', 'given-name': 'O', 'surname': 'Takahashi'},
#     {'@_fa': 'true', 'given-name': 'N', 'surname': 'Ishizuka'}]},
#   'dc:creator': 'T, Shimbo',
#   'dc:identifier': 'DOI:10.1016/S1098-3015(10)72088-X',
#   'dc:title': 'PMC45 INTEGRATED INTERPRETATION OF KAPPA WITH SENSITIVITY AND SPECIFICITY',
#   'eid': '1-s2.0-S109830151072088X',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S109830151072088X',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S109830151072088X',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': True,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/',
#   'pii': 'S1098-3015(10)72088-X',
#   'prism:coverDate': [{'$': '2010-05-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'May 2010',
#   'prism:doi': '10.1016/S1098-3015(10)72088-X',
#   'prism:issn': '10983015',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Value in Health',
#   'prism:startingPage': 'A22',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S109830151072088X',
#   'prism:volume': '13',
#   'pubType': 'POSTER SESSION ICONCEPTUAL PAPERS & RESEARCH ON METHODS – Statistical Methods'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'Roberto',
#      'surname': 'Coccurello'},
#     {'@_fa': 'true', 'given-name': 'Anna', 'surname': 'Moles'}]},
#   'dc:creator': 'Roberto, Coccurello',
#   'dc:identifier': 'DOI:10.1016/j.pharmthera.2010.04.008',
#   'dc:title': 'Potential mechanisms of atypical antipsychotic-induced metabolic derangement: Clues for understanding obesity and novel drug design',
#   'eid': '1-s2.0-S0163725810000938',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0163725810000938',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0163725810000938',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0163-7258(10)00093-8',
#   'prism:coverDate': [{'$': '2010-09-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'September 2010',
#   'prism:doi': '10.1016/j.pharmthera.2010.04.008',
#   'prism:endingPage': '251',
#   'prism:issn': '01637258',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Pharmacology & Therapeutics',
#   'prism:startingPage': '210',
#   'prism:teaser': 'Beside the therapeutic improvement over first-generation antipsychotics, the fact that prescription of atypical agents is also associated to the emergence of severe metabolic derangement in patients...',
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0163725810000938',
#   'prism:volume': '127'},
#  {'@_fa': 'true',
#   'dc:identifier': 'DOI:10.1159/000314328',
#   'dc:title': '42nd European Pancreatic Club (EPC) Meeting Abstracts June 16-19, 2010, Stockholm, Sweden',
#   'eid': '1-s2.0-S1424390310800869',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1424390310800869',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1424390310800869',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S1424-3903(10)80086-9',
#   'prism:coverDate': [{'$': '2010-06-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'June 2010',
#   'prism:doi': '10.1159/000314328',
#   'prism:endingPage': '400',
#   'prism:issn': '14243903',
#   'prism:issueIdentifier': '2',
#   'prism:publicationName': 'Pancreatology',
#   'prism:startingPage': '259',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1424390310800869',
#   'prism:volume': '10'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'AI',
#      'surname': 'Iaconi'},
#     {'@_fa': 'true', 'given-name': 'J', 'surname': 'Chang'},
#     {'@_fa': 'true', 'given-name': 'SR', 'surname': 'Feldman'},
#     {'@_fa': 'true', 'given-name': 'R', 'surname': 'Balkrishnan'}]},
#   'dc:creator': 'AI, Iaconi',
#   'dc:identifier': 'DOI:10.1016/S1098-3015(10)72085-4',
#   'dc:title': 'PMC42 EXAMINATION OF THE DIFFERENCES IN PATIENT SATISFACTION BETWEEN FIRST VISIT AND RETURN VISITS: ANALYSIS OF A USA SELF-REPORTED SURVEY DATA',
#   'eid': '1-s2.0-S1098301510720854',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1098301510720854',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1098301510720854',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': True,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/',
#   'pii': 'S1098-3015(10)72085-4',
#   'prism:coverDate': [{'$': '2010-05-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'May 2010',
#   'prism:doi': '10.1016/S1098-3015(10)72085-4',
#   'prism:endingPage': 'A22',
#   'prism:issn': '10983015',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Value in Health',
#   'prism:startingPage': 'A21',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1098301510720854',
#   'prism:volume': '13',
#   'pubType': 'POSTER SESSION ICONCEPTUAL PAPERS & RESEARCH ON METHODS – Patient-Reported Outcomes Studies'},
#  {'@_fa': 'true',
#   'authors': {'author': [{'@_fa': 'true',
#      'given-name': 'D',
#      'surname': 'Gause'},
#     {'@_fa': 'true', 'given-name': 'P', 'surname': 'Gause'}]},
#   'dc:creator': 'D, Gause',
#   'dc:identifier': 'DOI:10.1016/S1098-3015(10)72090-8',
#   'dc:title': 'PMC47 STATISTICAL METHODS NEEDED IN HEALTH ECONOMICS',
#   'eid': '1-s2.0-S1098301510720908',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1098301510720908',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1098301510720908',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': True,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/',
#   'pii': 'S1098-3015(10)72090-8',
#   'prism:coverDate': [{'$': '2010-05-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'May 2010',
#   'prism:doi': '10.1016/S1098-3015(10)72090-8',
#   'prism:endingPage': 'A23',
#   'prism:issn': '10983015',
#   'prism:issueIdentifier': '3',
#   'prism:publicationName': 'Value in Health',
#   'prism:startingPage': 'A22',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1098301510720908',
#   'prism:volume': '13',
#   'pubType': 'POSTER SESSION ICONCEPTUAL PAPERS & RESEARCH ON METHODS – Statistical Methods'},
#  {'@_fa': 'true',
#   'dc:identifier': 'DOI:10.1016/j.biopsych.2010.03.009',
#   'dc:title': 'Saturday Abstracts',
#   'eid': '1-s2.0-S0006322310002374',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0006322310002374',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0006322310002374',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0006-3223(10)00237-4',
#   'prism:coverDate': [{'$': '2010-05-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': '1 May 2010',
#   'prism:doi': '10.1016/j.biopsych.2010.03.009',
#   'prism:endingPage': '271S',
#   'prism:issn': '00063223',
#   'prism:issueIdentifier': '9',
#   'prism:issueName': 'Sixty-Fifth Annual Scientific Convention and Meeting',
#   'prism:publicationName': 'Biological Psychiatry',
#   'prism:startingPage': '178S',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0006322310002374',
#   'prism:volume': '67',
#   'pubType': 'Abstract'},
#  {'@_fa': 'true',
#   'dc:identifier': 'DOI:10.1016/S0748-7983(10)00156-3',
#   'dc:title': 'Abstracts',
#   'eid': '1-s2.0-S0748798310001563',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S0748798310001563',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S0748798310001563',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': False,
#   'openaccess': '0',
#   'openaccessArticle': False,
#   'openaccessUserLicense': None,
#   'pii': 'S0748-7983(10)00156-3',
#   'prism:coverDate': [{'$': '2010-09-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'September 2010',
#   'prism:doi': '10.1016/S0748-7983(10)00156-3',
#   'prism:endingPage': '932',
#   'prism:issn': '07487983',
#   'prism:issueIdentifier': '9',
#   'prism:issueName': '15th Congress of the European Society of Surgical Oncology',
#   'prism:publicationName': 'European Journal of Surgical Oncology (EJSO)',
#   'prism:startingPage': '795',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S0748798310001563',
#   'prism:volume': '36'},
#  {'@_fa': 'true',
#   'dc:identifier': 'DOI:10.1016/j.ijid.2010.02.002',
#   'dc:title': 'Abstracts for Supplement',
#   'eid': '1-s2.0-S1201971210000342',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1201971210000342',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1201971210000342',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': True,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/',
#   'pii': 'S1201-9712(10)00034-2',
#   'prism:coverDate': [{'$': '2010-03-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'March 2010',
#   'prism:doi': '10.1016/j.ijid.2010.02.002',
#   'prism:endingPage': 'e478',
#   'prism:issn': '12019712',
#   'prism:issueIdentifier': None,
#   'prism:issueName': '14th International Congress on Infectious Diseases (ICID) Abstracts',
#   'prism:publicationName': 'International Journal of Infectious Diseases',
#   'prism:startingPage': 'e335',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1201971210000342',
#   'prism:volume': '14'},
#  {'@_fa': 'true',
#   'dc:identifier': 'DOI:10.1016/j.ijid.2010.02.001',
#   'dc:title': 'Abstracts for Supplement',
#   'eid': '1-s2.0-S1201971210000330',
#   'link': [{'@_fa': 'true',
#     '@href': 'https://api.elsevier.com/content/article/pii/S1201971210000330',
#     '@ref': 'self'},
#    {'@_fa': 'true',
#     '@href': 'https://www.sciencedirect.com/science/article/pii/S1201971210000330',
#     '@ref': 'scidir'}],
#   'openArchiveArticle': True,
#   'openaccess': '1',
#   'openaccessArticle': True,
#   'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/',
#   'pii': 'S1201-9712(10)00033-0',
#   'prism:coverDate': [{'$': '2010-03-01', '@_fa': 'true'}],
#   'prism:coverDisplayDate': 'March 2010',
#   'prism:doi': '10.1016/j.ijid.2010.02.001',
#   'prism:endingPage': 'e335',
#   'prism:issn': '12019712',
#   'prism:issueIdentifier': None,
#   'prism:issueName': '14th International Congress on Infectious Diseases (ICID) Abstracts',
#   'prism:publicationName': 'International Journal of Infectious Diseases',
#   'prism:startingPage': 'e191',
#   'prism:teaser': None,
#   'prism:url': 'https://api.elsevier.com/content/article/pii/S1201971210000330',
#   'prism:volume': '14'}]

# %%
searcher.results[0]
# Out:
# {'@_fa': 'true',
#  'authors': {'author': [{'@_fa': 'true',
#     'given-name': 'Viroj',
#     'surname': 'Wiwanitkit'}]},
#  'dc:creator': 'Viroj, Wiwanitkit',
#  'dc:identifier': 'DOI:10.1016/j.ejim.2017.06.007',
#  'dc:title': 'Eye problem in Zika virus infection',
#  'eid': '1-s2.0-S0953620517302352',
#  'link': [{'@_fa': 'true',
#    '@href': 'https://api.elsevier.com/content/article/pii/S0953620517302352',
#    '@ref': 'self'},
#   {'@_fa': 'true',
#    '@href': 'https://www.sciencedirect.com/science/article/pii/S0953620517302352',
#    '@ref': 'scidir'}],
#  'openArchiveArticle': False,
#  'openaccess': '0',
#  'openaccessArticle': False,
#  'openaccessUserLicense': None,
#  'pii': 'S0953-6205(17)30235-2',
#  'prism:coverDate': [{'$': '2018-01-01', '@_fa': 'true'}],
#  'prism:coverDisplayDate': 'January 2018',
#  'prism:doi': '10.1016/j.ejim.2017.06.007',
#  'prism:issn': '09536205',
#  'prism:issueIdentifier': None,
#  'prism:publicationName': 'European Journal of Internal Medicine',
#  'prism:startingPage': 'e17',
#  'prism:teaser': None,
#  'prism:url': 'https://api.elsevier.com/content/article/pii/S0953620517302352',
#  'prism:volume': '47',
#  'pubType': 'Letter to the Editor'}

# %%
cd apps
# Out:
# /Users/sedir/System/LAIS/Python/bibliographic-reviewer/atena/atena/apps

# %%
from abc import ABC, abstractmethod


class AbstractSerializer(ABC):
    @abstractmethod
    def parse(self, data):
        pass


class ElsevierSerializer(AbstractSerializer):
    def parse(self, data):
        total_list = list()
        if type(data)==list:
            for item in data:
                total_list.append(self.parse_item(item))
        else:
            total_list.append(self.parse_item(item))
        return total_list
    
    def parse_item(self, item):
        documento = dict()
        documento['titulo'] = item['dc:title']
        try:
            documento['autores'] = item['dc:creator']
        except:
            print(item)
        documento['doi'] = item['prism:doi']
        documento['revista'] = item['prism:publicationName']
        documento['html_url'] = item['prism:url']
#         documento['citado_papers'] = item['citedby-count']
#         documento['data'] = item['prism:coverDate']
        return documento

# %%
serializer = ElsevierSerializer()
filtered = serializer.parse(searcher.results)
# Out:
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0165011410003325'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0165011410003325'}], 'dc:identifier': 'DOI:10.1016/j.fss.2010.08.009', 'eid': '1-s2.0-S0165011410003325', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0165011410003325', 'dc:title': 'Recent Literature', 'prism:publicationName': 'Fuzzy Sets and Systems', 'prism:issueName': 'Theme: Algebraic Aspects of Fuzzy Sets', 'prism:issn': '01650114', 'prism:volume': '161', 'prism:issueIdentifier': '24', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-12-16'}], 'prism:coverDisplayDate': '16 December 2010', 'prism:startingPage': '3174', 'prism:endingPage': '3181', 'prism:doi': '10.1016/j.fss.2010.08.009', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0165-0114(10)00332-5', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0914508710001930'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0914508710001930'}], 'dc:identifier': 'DOI:10.1016/S0914-5087(10)00193-0', 'eid': '1-s2.0-S0914508710001930', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0914508710001930', 'dc:title': 'Keywords list', 'prism:publicationName': 'Journal of Cardiology', 'prism:issn': '09145087', 'prism:volume': '56', 'prism:issueIdentifier': '3', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-11-01'}], 'prism:coverDisplayDate': 'November 2010', 'prism:startingPage': 'VIII', 'prism:endingPage': 'X', 'prism:doi': '10.1016/S0914-5087(10)00193-0', 'openaccess': '1', 'openaccessArticle': True, 'openArchiveArticle': True, 'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/', 'pii': 'S0914-5087(10)00193-0', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0302283810009759'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0302283810009759'}], 'dc:identifier': 'DOI:10.1016/S0302-2838(10)00975-9', 'eid': '1-s2.0-S0302283810009759', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0302283810009759', 'dc:title': 'Award pages', 'prism:publicationName': 'European Urology', 'prism:issn': '03022838', 'prism:volume': '58', 'prism:issueIdentifier': '6', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-12-01'}], 'prism:coverDisplayDate': 'December 2010', 'prism:startingPage': 'ii', 'prism:endingPage': 'iv', 'prism:doi': '10.1016/S0302-2838(10)00975-9', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0302-2838(10)00975-9', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0302283810008079'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0302283810008079'}], 'dc:identifier': 'DOI:10.1016/S0302-2838(10)00807-9', 'eid': '1-s2.0-S0302283810008079', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0302283810008079', 'dc:title': 'Award pages', 'prism:publicationName': 'European Urology', 'prism:issn': '03022838', 'prism:volume': '58', 'prism:issueIdentifier': '5', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-11-01'}], 'prism:coverDisplayDate': 'November 2010', 'prism:startingPage': 'ii', 'prism:endingPage': 'iv', 'prism:doi': '10.1016/S0302-2838(10)00807-9', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0302-2838(10)00807-9', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0302283810007633'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0302283810007633'}], 'dc:identifier': 'DOI:10.1016/S0302-2838(10)00763-3', 'eid': '1-s2.0-S0302283810007633', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0302283810007633', 'dc:title': 'Award Pages', 'prism:publicationName': 'European Urology', 'prism:issn': '03022838', 'prism:volume': '58', 'prism:issueIdentifier': '4', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-10-01'}], 'prism:coverDisplayDate': 'October 2010', 'prism:startingPage': 'ii', 'prism:endingPage': 'iv', 'prism:doi': '10.1016/S0302-2838(10)00763-3', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0302-2838(10)00763-3', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0302283810006251'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0302283810006251'}], 'dc:identifier': 'DOI:10.1016/S0302-2838(10)00625-1', 'eid': '1-s2.0-S0302283810006251', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0302283810006251', 'dc:title': 'Award pages', 'prism:publicationName': 'European Urology', 'prism:issn': '03022838', 'prism:volume': '58', 'prism:issueIdentifier': '3', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-09-01'}], 'prism:coverDisplayDate': 'September 2010', 'prism:startingPage': 'ii', 'prism:endingPage': 'iv', 'prism:doi': '10.1016/S0302-2838(10)00625-1', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0302-2838(10)00625-1', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0302283810004987'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0302283810004987'}], 'dc:identifier': 'DOI:10.1016/S0302-2838(10)00498-7', 'eid': '1-s2.0-S0302283810004987', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0302283810004987', 'dc:title': 'Award pages', 'prism:publicationName': 'European Urology', 'prism:issn': '03022838', 'prism:volume': '58', 'prism:issueIdentifier': '2', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-08-01'}], 'prism:coverDisplayDate': 'August 2010', 'prism:startingPage': 'ii', 'prism:endingPage': 'iv', 'prism:doi': '10.1016/S0302-2838(10)00498-7', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0302-2838(10)00498-7', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0301562910005922'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0301562910005922'}], 'dc:identifier': 'DOI:10.1016/S0301-5629(10)00592-2', 'eid': '1-s2.0-S0301562910005922', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0301562910005922', 'dc:title': 'Subject Index', 'prism:publicationName': 'Ultrasound in Medicine & Biology', 'prism:issn': '03015629', 'prism:volume': '36', 'prism:issueIdentifier': '12', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-12-01'}], 'prism:coverDisplayDate': 'December 2010', 'prism:startingPage': 'e1', 'prism:endingPage': 'e34', 'prism:doi': '10.1016/S0301-5629(10)00592-2', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0301-5629(10)00592-2', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0889852910000599'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0889852910000599'}], 'dc:identifier': 'DOI:10.1016/S0889-8529(10)00059-9', 'eid': '1-s2.0-S0889852910000599', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0889852910000599', 'dc:title': 'Index', 'prism:publicationName': 'Endocrinology and Metabolism Clinics of North America', 'prism:issueName': 'Type I Diabetes', 'prism:issn': '08898529', 'prism:volume': '39', 'prism:issueIdentifier': '3', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-09-01'}], 'prism:coverDisplayDate': 'September 2010', 'prism:startingPage': '669', 'prism:endingPage': '695', 'prism:doi': '10.1016/S0889-8529(10)00059-9', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0889-8529(10)00059-9', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S1550830710000947'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S1550830710000947'}], 'dc:identifier': 'DOI:10.1016/j.explore.2010.04.004', 'eid': '1-s2.0-S1550830710000947', 'prism:url': 'https://api.elsevier.com/content/article/pii/S1550830710000947', 'dc:title': 'A Challenge to Science', 'prism:publicationName': 'EXPLORE: The Journal of Science and Healing', 'prism:issn': '15508307', 'prism:volume': '6', 'prism:issueIdentifier': '4', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-07-01'}], 'prism:coverDisplayDate': 'July–August 2010', 'prism:startingPage': '197', 'prism:endingPage': '214', 'prism:doi': '10.1016/j.explore.2010.04.004', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pubType': 'Explorations', 'pii': 'S1550-8307(10)00094-7', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S1547527110002729'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S1547527110002729'}], 'dc:identifier': 'DOI:10.1016/j.hrthm.2010.03.030', 'eid': '1-s2.0-S1547527110002729', 'prism:url': 'https://api.elsevier.com/content/article/pii/S1547527110002729', 'dc:title': 'Poster Session 2 (PO2-01 to PO2-171)', 'prism:publicationName': 'Heart Rhythm', 'prism:issueName': 'Heart Rhythm 2010', 'prism:issn': '15475271', 'prism:volume': '7', 'prism:issueIdentifier': '5', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-05-01'}], 'prism:coverDisplayDate': 'May 2010', 'prism:startingPage': 'S131', 'prism:endingPage': 'S195', 'prism:doi': '10.1016/j.hrthm.2010.03.030', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pubType': 'Featured poster', 'pii': 'S1547-5271(10)00272-9', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0015028210007077'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0015028210007077'}], 'dc:identifier': 'DOI:10.1016/S0015-0282(10)00707-7', 'eid': '1-s2.0-S0015028210007077', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0015028210007077', 'dc:title': 'Author Index to Volume 93', 'prism:publicationName': 'Fertility and Sterility', 'prism:issn': '00150282', 'prism:volume': '93', 'prism:issueIdentifier': '8', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-05-15'}], 'prism:coverDisplayDate': '15 May 2010', 'prism:startingPage': '2774', 'prism:endingPage': '2800', 'prism:doi': '10.1016/S0015-0282(10)00707-7', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pubType': 'Index', 'pii': 'S0015-0282(10)00707-7', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0167814010800362'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0167814010800362'}], 'dc:identifier': 'DOI:10.1016/S0167-8140(10)80036-2', 'eid': '1-s2.0-S0167814010800362', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0167814010800362', 'dc:title': 'Symposium', 'prism:publicationName': 'Radiotherapy and Oncology', 'prism:issueName': 'ESTRO 29', 'prism:issn': '01678140', 'prism:volume': '96', 'prism:issueIdentifier': None, 'prism:coverDate': [{'@_fa': 'true', '$': '2010-09-01'}], 'prism:coverDisplayDate': 'September 2010', 'prism:startingPage': 'S103', 'prism:endingPage': 'S111', 'prism:doi': '10.1016/S0167-8140(10)80036-2', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0167-8140(10)80036-2', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S1424390310800869'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S1424390310800869'}], 'dc:identifier': 'DOI:10.1159/000314328', 'eid': '1-s2.0-S1424390310800869', 'prism:url': 'https://api.elsevier.com/content/article/pii/S1424390310800869', 'dc:title': '42nd European Pancreatic Club (EPC) Meeting Abstracts June 16-19, 2010, Stockholm, Sweden', 'prism:publicationName': 'Pancreatology', 'prism:issn': '14243903', 'prism:volume': '10', 'prism:issueIdentifier': '2', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-06-01'}], 'prism:coverDisplayDate': 'June 2010', 'prism:startingPage': '259', 'prism:endingPage': '400', 'prism:doi': '10.1159/000314328', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S1424-3903(10)80086-9', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0006322310002374'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0006322310002374'}], 'dc:identifier': 'DOI:10.1016/j.biopsych.2010.03.009', 'eid': '1-s2.0-S0006322310002374', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0006322310002374', 'dc:title': 'Saturday Abstracts', 'prism:publicationName': 'Biological Psychiatry', 'prism:issueName': 'Sixty-Fifth Annual Scientific Convention and Meeting', 'prism:issn': '00063223', 'prism:volume': '67', 'prism:issueIdentifier': '9', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-05-01'}], 'prism:coverDisplayDate': '1 May 2010', 'prism:startingPage': '178S', 'prism:endingPage': '271S', 'prism:doi': '10.1016/j.biopsych.2010.03.009', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pubType': 'Abstract', 'pii': 'S0006-3223(10)00237-4', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S0748798310001563'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S0748798310001563'}], 'dc:identifier': 'DOI:10.1016/S0748-7983(10)00156-3', 'eid': '1-s2.0-S0748798310001563', 'prism:url': 'https://api.elsevier.com/content/article/pii/S0748798310001563', 'dc:title': 'Abstracts', 'prism:publicationName': 'European Journal of Surgical Oncology (EJSO)', 'prism:issueName': '15th Congress of the European Society of Surgical Oncology', 'prism:issn': '07487983', 'prism:volume': '36', 'prism:issueIdentifier': '9', 'prism:coverDate': [{'@_fa': 'true', '$': '2010-09-01'}], 'prism:coverDisplayDate': 'September 2010', 'prism:startingPage': '795', 'prism:endingPage': '932', 'prism:doi': '10.1016/S0748-7983(10)00156-3', 'openaccess': '0', 'openaccessArticle': False, 'openArchiveArticle': False, 'openaccessUserLicense': None, 'pii': 'S0748-7983(10)00156-3', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S1201971210000342'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S1201971210000342'}], 'dc:identifier': 'DOI:10.1016/j.ijid.2010.02.002', 'eid': '1-s2.0-S1201971210000342', 'prism:url': 'https://api.elsevier.com/content/article/pii/S1201971210000342', 'dc:title': 'Abstracts for Supplement', 'prism:publicationName': 'International Journal of Infectious Diseases', 'prism:issueName': '14th International Congress on Infectious Diseases (ICID) Abstracts', 'prism:issn': '12019712', 'prism:volume': '14', 'prism:issueIdentifier': None, 'prism:coverDate': [{'@_fa': 'true', '$': '2010-03-01'}], 'prism:coverDisplayDate': 'March 2010', 'prism:startingPage': 'e335', 'prism:endingPage': 'e478', 'prism:doi': '10.1016/j.ijid.2010.02.002', 'openaccess': '1', 'openaccessArticle': True, 'openArchiveArticle': True, 'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/', 'pii': 'S1201-9712(10)00034-2', 'prism:teaser': None}
# {'@_fa': 'true', 'link': [{'@_fa': 'true', '@ref': 'self', '@href': 'https://api.elsevier.com/content/article/pii/S1201971210000330'}, {'@_fa': 'true', '@ref': 'scidir', '@href': 'https://www.sciencedirect.com/science/article/pii/S1201971210000330'}], 'dc:identifier': 'DOI:10.1016/j.ijid.2010.02.001', 'eid': '1-s2.0-S1201971210000330', 'prism:url': 'https://api.elsevier.com/content/article/pii/S1201971210000330', 'dc:title': 'Abstracts for Supplement', 'prism:publicationName': 'International Journal of Infectious Diseases', 'prism:issueName': '14th International Congress on Infectious Diseases (ICID) Abstracts', 'prism:issn': '12019712', 'prism:volume': '14', 'prism:issueIdentifier': None, 'prism:coverDate': [{'@_fa': 'true', '$': '2010-03-01'}], 'prism:coverDisplayDate': 'March 2010', 'prism:startingPage': 'e191', 'prism:endingPage': 'e335', 'prism:doi': '10.1016/j.ijid.2010.02.001', 'openaccess': '1', 'openaccessArticle': True, 'openArchiveArticle': True, 'openaccessUserLicense': 'http://www.elsevier.com/open-access/userlicense/1.0/', 'pii': 'S1201-9712(10)00033-0', 'prism:teaser': None}

# %%
[x for x in filtered if x['titulo']=='Award pages']
# Out:
# [{'doi': '10.1016/S0302-2838(10)00975-9',
#   'html_url': 'https://api.elsevier.com/content/article/pii/S0302283810009759',
#   'revista': 'European Urology',
#   'titulo': 'Award pages'},
#  {'doi': '10.1016/S0302-2838(10)00807-9',
#   'html_url': 'https://api.elsevier.com/content/article/pii/S0302283810008079',
#   'revista': 'European Urology',
#   'titulo': 'Award pages'},
#  {'doi': '10.1016/S0302-2838(10)00625-1',
#   'html_url': 'https://api.elsevier.com/content/article/pii/S0302283810006251',
#   'revista': 'European Urology',
#   'titulo': 'Award pages'},
#  {'doi': '10.1016/S0302-2838(10)00498-7',
#   'html_url': 'https://api.elsevier.com/content/article/pii/S0302283810004987',
#   'revista': 'European Urology',
#   'titulo': 'Award pages'}]
